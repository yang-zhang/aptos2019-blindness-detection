# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

import pandas as pd
import numpy as np
from pathlib import Path


def nfiles(pp):
    return len(list(pp.iterdir()))

def show_sample_images(p):
    fns = np.random.choice(list(p.iterdir()), 10)
    for i, fn in enumerate(fns):
        fig=plt.figure(figsize=(2, 2))
        im = Image.open(fn)
        plt.title(fn)
        plt.imshow(im)

# %%
p_prp = '../output/Prep0703/'

# %% [markdown]
# # aptos2019-blindness-detection

# %% [markdown]
# ## images

# %%
p = '../input/aptos2019-blindness-detection'
pp = Path(p)

# %%
nfiles(pp/'train_images'), nfiles(pp/'test_images')
# Out:
# (3662, 1928)

# %%
show_sample_images(pp/'train_images')

# %%
show_sample_images(pp/'test_images')

# %% [markdown]
# ## images cropped

# %%
p = f'{p_prp}/aptos2019-blindness-detection/'
pp = Path(p)

# %%
nfiles(pp/'train_images'), nfiles(pp/'test_images')
# Out:
# (3662, 1928)

# %%
show_sample_images(pp/'train_images')

# %%
show_sample_images(pp/'test_images')

# %% [markdown]
# ## labels

# %%
p = '../input/aptos2019-blindness-detection'
pp = Path(p)

# %%
train=pd.read_csv(pp/'train.csv')
test =pd.read_csv(pp/'test.csv')
sample_submission =pd.read_csv(pp/'sample_submission.csv')

train.shape, test.shape, sample_submission.shape
# Out:
# ((3662, 2), (1928, 1), (1928, 2))

# %%
train.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
test.head()
# Out:
#         id_code
# 0  0005cfc8afb6
# 1  003f0afdcd15
# 2  006efc72b638
# 3  00836aaacf06
# 4  009245722fa4

# %%
sample_submission.head()
# Out:
#         id_code  diagnosis
# 0  0005cfc8afb6          0
# 1  003f0afdcd15          0
# 2  006efc72b638          0
# 3  00836aaacf06          0
# 4  009245722fa4          0

# %% [markdown]
# https://www.kaggle.com/c/aptos2019-blindness-detection/data
# You can plan on the private test set consisting of 20GB of data across 13,000 images (approximately).

# %%
f'Private testset is {13000 / len(test): .2f} times the size of public test set!'
# Out:
# 'Private testset is  6.74 times the size of public test set!'

# %% [markdown]
# ## stats

# %%
target = 'diagnosis'

# %%
train[target].value_counts()/len(train)
# Out:
# 0    0.492900
# 2    0.272802
# 1    0.101038
# 4    0.080557
# 3    0.052703
# Name: diagnosis, dtype: float64

# %%
train[target].value_counts().sort_index()/len(train)
# Out:
# 0    0.492900
# 1    0.101038
# 2    0.272802
# 3    0.052703
# 4    0.080557
# Name: diagnosis, dtype: float64

# %%
train[target][train[target]>0].value_counts().sort_index()/len(train)
# Out:
# 1    0.101038
# 2    0.272802
# 3    0.052703
# 4    0.080557
# Name: diagnosis, dtype: float64

# %%
(train[target]>0).value_counts()/len(train)
# Out:
# True     0.5071
# False    0.4929
# Name: diagnosis, dtype: float64

# %% [markdown]
# # diabetic-retinopathy-detection

# %% [markdown]
# ## images

# %%
p = '../input/diabetic-retinopathy-detection'
pp = Path(p)

# %%
nfiles(pp/'train_images'), nfiles(pp/'test_images')
# Out:
# (35126, 53576)

# %%
show_sample_images(pp/'train_images')

# %%
show_sample_images(pp/'test_images')

# %% [markdown]
# ## images cropped

# %%
p = f'{p_prp}/diabetic-retinopathy-detection/'
pp = Path(p)

# %%
nfiles(pp/'train_images'), nfiles(pp/'test_images')
# Out:
# (35126, 7636)

# %%
show_sample_images(pp/'train_images')

# %%
show_sample_images(pp/'test_images')

# %% [markdown]
# ## labels

# %%
p = '../input/diabetic-retinopathy-detection'
pp = Path(p)

# %%
train=pd.read_csv(pp/'trainLabels.csv')
test=pd.read_csv(pp/'retinopathy_solution.csv')
sample_submission =pd.read_csv(pp/'sampleSubmission.csv')

train.shape, test.shape, sample_submission.shape
# Out:
# ((35126, 2), (53576, 3), (53576, 2))

# %%
train.head()
# Out:
#       image  level
# 0   10_left      0
# 1  10_right      0
# 2   13_left      0
# 3  13_right      0
# 4   15_left      1

# %%
test.head(100)
# Out:
#        image  level    Usage
# 0     1_left      0  Private
# 1    1_right      0  Private
# 2     2_left      0   Public
# 3    2_right      0   Public
# 4     3_left      2  Private
# 5    3_right      2  Private
# 6     4_left      2  Private
# 7    4_right      2  Private
# 8     5_left      0  Private
# 9    5_right      0  Private
# 10    6_left      1  Private
# 11   6_right      1  Private
# 12    7_left      0   Public
# 13   7_right      0   Public
# 14    8_left      2  Private
# 15   8_right      2  Private
# 16    9_left      4  Private
# 17   9_right      4  Private
# 18   11_left      0  Private
# 19  11_right      0  Private
# 20   12_left      0   Public
# 21  12_right      0   Public
# 22   14_left      0  Private
# 23  14_right      0  Private
# 24   18_left      0  Private
# 25  18_right      0  Private
# 26   24_left      0  Private
# 27  24_right      0  Private
# 28   26_left      0  Private
# 29  26_right      0  Private
# ..       ...    ...      ...
# 70   71_left      0  Private
# 71  71_right      0  Private
# 72   76_left      0  Private
# 73  76_right      0  Private
# 74   77_left      0  Private
# 75  77_right      0  Private
# 76   80_left      2  Private
# 77  80_right      2  Private
# 78   83_left      0  Private
# 79  83_right      1  Private
# 80   85_left      0  Private
# 81  85_right      0  Private
# 82   86_left      0  Private
# 83  86_right      0  Private
# 84   87_left      0  Private
# 85  87_right      0  Private
# 86   88_left      2  Private
# 87  88_right      2  Private
# 88   89_left      2  Private
# 89  89_right      0  Private
# 90   90_left      0   Public
# 91  90_right      2   Public
# 92   91_left      0  Private
# 93  91_right      0  Private
# 94   92_left      2   Public
# 95  92_right      2   Public
# 96   93_left      0  Private
# 97  93_right      0  Private
# 98   94_left      0  Private
# 99  94_right      0  Private
#
# [100 rows x 3 columns]

# %%
sample_submission.head()
# Out:
#      image  level
# 0   1_left      0
# 1  1_right      0
# 2   2_left      0
# 3  2_right      0
# 4   3_left      0

# %% [markdown]
# Be careful using the testset:
#
# https://www.kaggle.com/c/diabetic-retinopathy-detection/discussion/16149#349587
#
# Hello, are the labels good for you? we found that our model can not convergence on the validation data from the test dataset, is your model work well on the test data by this label file?
#
# No actually mine is not converge either. do you know what is the problem?
#
# Hey, did you figure out the problem of non-convergence?

# %% [markdown]
# ## stats

# %%
target = 'level'

# %%
train[target].value_counts()/len(train)
# Out:
# 0    0.734783
# 2    0.150658
# 1    0.069550
# 3    0.024853
# 4    0.020156
# Name: level, dtype: float64

# %%
train[target].value_counts().sort_index()/len(train)
# Out:
# 0    0.734783
# 1    0.069550
# 2    0.150658
# 3    0.024853
# 4    0.020156
# Name: level, dtype: float64

# %%
train[target][train[target]>0].value_counts().sort_index()/len(train)
# Out:
# 1    0.069550
# 2    0.150658
# 3    0.024853
# 4    0.020156
# Name: level, dtype: float64

# %%
(train[target]>0).value_counts()/len(train)
# Out:
# False    0.734783
# True     0.265217
# Name: level, dtype: float64

# %% [markdown]
# # IDRID

# %% [markdown]
# ## images

# %%
p = '../input/IDRID/B. Disease Grading/'
pp = Path(p)

# %%
nfiles(pp/'1. Original Images/a. Training Set'), nfiles(pp/'1. Original Images/b. Testing Set')
# Out:
# (413, 103)

# %%
show_sample_images(pp/'1. Original Images/a. Training Set')

# %%
show_sample_images(pp/'1. Original Images/b. Testing Set')

# %% [markdown]
# ## images cropped

# %%
p = f'{p_prp}/IDRID/B. Disease Grading/'
pp = Path(p)

# %%
nfiles(pp/'1. Original Images/a. Training Set'), nfiles(pp/'1. Original Images/b. Testing Set')
# Out:
# (413, 103)

# %%
show_sample_images(pp/'1. Original Images/a. Training Set')

# %%
show_sample_images(pp/'1. Original Images/b. Testing Set')

# %% [markdown]
# ## labels

# %%
p = '../input/IDRID/B. Disease Grading/'
pp = Path(p)

# %%
train=pd.read_csv(pp/'2. Groundtruths/a. IDRiD_Disease Grading_Training Labels.csv')
test = pd.read_csv(pp/'2. Groundtruths/b. IDRiD_Disease Grading_Testing Labels.csv')

train.shape, test.shape
# Out:
# ((413, 12), (103, 3))

# %%
train.head()
# Out:
#   Image name  Retinopathy grade  Risk of macular edema   Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0  IDRiD_001                  3                       2         NaN         NaN         NaN         NaN         NaN         NaN         NaN          NaN         NaN
# 1  IDRiD_002                  3                       2         NaN         NaN         NaN         NaN         NaN         NaN         NaN          NaN         NaN
# 2  IDRiD_003                  2                       2         NaN         NaN         NaN         NaN         NaN         NaN         NaN          NaN         NaN
# 3  IDRiD_004                  3                       2         NaN         NaN         NaN         NaN         NaN         NaN         NaN          NaN         NaN
# 4  IDRiD_005                  4                       0         NaN         NaN         NaN         NaN         NaN         NaN         NaN          NaN         NaN

# %%
test.head()
# Out:
#   Image name  Retinopathy grade  Risk of macular edema
# 0  IDRiD_001                  4                       0
# 1  IDRiD_002                  4                       1
# 2  IDRiD_003                  4                       0
# 3  IDRiD_004                  4                       0
# 4  IDRiD_005                  4                       1

# %% [markdown]
# ## stats

# %%
target = 'Retinopathy grade'

# %%
train[target].value_counts()/len(train)
# Out:
# 2    0.329298
# 0    0.324455
# 3    0.179177
# 4    0.118644
# 1    0.048426
# Name: Retinopathy grade, dtype: float64

# %%
train[target].value_counts().sort_index()/len(train)
# Out:
# 0    0.324455
# 1    0.048426
# 2    0.329298
# 3    0.179177
# 4    0.118644
# Name: Retinopathy grade, dtype: float64

# %%
train[target][train[target]>0].value_counts().sort_index()/len(train)
# Out:
# 1    0.048426
# 2    0.329298
# 3    0.179177
# 4    0.118644
# Name: Retinopathy grade, dtype: float64

# %%
(train[target]>0).value_counts()/len(train)
# Out:
# True     0.675545
# False    0.324455
# Name: Retinopathy grade, dtype: float64
